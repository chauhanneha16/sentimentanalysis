# %% [markdown]
# <a href="https://colab.research.google.com/github/chauhanneha16/sentimentanalysis/blob/main/EMOTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install torch
# !pip install datasets
# !pip install translate
# !pip install scikit-learn
# !pip install matplotlib
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.40.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.2.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 20.4 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Collecting huggingface-hub>=0.21.2 (from datasets)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-2.19.1 dill-0.3.8 huggingface-hub-0.23.0 multiprocess-0.70.16 xxhash-3.4.1
# Collecting translate
#   Downloading translate-3.6.1-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from translate) (8.1.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from translate) (4.9.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from translate) (2.31.0)
# Collecting libretranslatepy==2.1.1 (from translate)
#   Downloading libretranslatepy-2.1.1-py3-none-any.whl (3.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->translate) (2024.2.2)
# Installing collected packages: libretranslatepy, translate
# Successfully installed libretranslatepy-2.1.1 translate-3.6.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from datasets import load_dataset
import torch
import torch.nn.functional as F
from translate import Translator
from sklearn.model_selection import train_test_split

# Function to translate text in batches to manage memory usage
def translate_text_batch(texts, target_language, batch_size=100):
    translations = []
    translator = Translator(to_lang=target_language)
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i + batch_size]
        try:
            batch_translations = [translator.translate(text) for text in batch]
            translations.extend(batch_translations)
        except Exception as e:
            print(f"Error translating batch to {target_language}: {e}")
            translations.extend([None] * len(batch))
    return translations

# Load GoEmotions dataset
dataset = load_dataset("go_emotions", split="train[:5000]")  # Use a subset for demonstration

# Mapping GoEmotions labels to custom emotion categories
emotion_mapping = {0: "admiration", 1: "amusement", 2: "anger", 3: "annoyance", 4: "approval", 5: "caring",
                   6: "confusion", 7: "curiosity", 8: "desire", 9: "disappointment", 10: "disapproval",
                   11: "disgust", 12: "embarrassment", 13: "excitement", 14: "fear", 15: "gratitude",
                   16: "grief", 17: "joy", 18: "love", 19: "nervousness", 20: "optimism", 21: "pride",
                   22: "realization", 23: "relief", 24: "remorse", 25: "sadness", 26: "surprise"}

# Define custom emotion labels for the emotions we are interested in
custom_emotion_labels = {"joy": 0, "sadness": 1, "anger": 2, "fear": 3, "surprise": 4}

# Filter sentences to only include those with emotions in custom_emotion_labels
filtered_sentences = {}
for example in dataset:
    try:
        emotion = emotion_mapping[example['labels'][0]]
        if emotion in custom_emotion_labels:
            filtered_sentences[example['text']] = example['labels'][0]
    except KeyError:
        continue

# Map the labels to custom emotion labels
filtered_sentences = {text: custom_emotion_labels[emotion_mapping[label]] for text, label in filtered_sentences.items()}

# Split into train and test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    list(filtered_sentences.keys()),
    list(filtered_sentences.values()),
    test_size=0.2,
    random_state=42
)

# Translate test sentences
translations = {
    "Japanese": translate_text_batch(test_texts, 'ja'),
    "German": translate_text_batch(test_texts, 'de'),
    "Spanish": translate_text_batch(test_texts, 'es'),
    "Italian": translate_text_batch(test_texts, 'it')
}

# Print translations for verification
for lang, translated_texts in translations.items():
    print(f"\nTranslations in {lang}:")
    for original, translation in zip(test_texts, translated_texts):
        if translation:
            print(f"{original} -> {translation}")
        else:
            print(f"{original} -> Translation failed")

# Load multilingual emotion recognition models
model_names = {
    "RoBERTa": "j-hartmann/emotion-english-distilroberta-base",
    "DistilBERT": "bhadresh-savani/distilbert-base-uncased-emotion",
    "BERT": "finiteautomata/bertweet-base-sentiment-analysis",
    "XLM-RoBERTa": "joeddav/xlm-roberta-large-xnli"
}

huggingface_token = "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"

# Function to get emotion from text using the specified model
def get_emotion(text, tokenizer, model):
    inputs = tokenizer(text, return_tensors="pt", truncation=True)
    outputs = model(**inputs)
    probs = F.softmax(outputs.logits, dim=1)
    label = torch.argmax(probs).item()
    return label

# Map emotions to numerical labels for consistency
emotion_labels = {
    "joy": 0,
    "sadness": 1,
    "anger": 2,
    "fear": 3,
    "surprise": 4
}

# Predict emotions using the model
def predict_emotions(data, tokenizer, model):
    return [get_emotion(text, tokenizer, model) for text in data]

# Evaluate model
def evaluate_model(predictions, labels):
    acc = accuracy_score(labels, predictions)
    cm = confusion_matrix(labels, predictions, labels=list(emotion_labels.values()))
    return acc, cm

# Calculate EER with error handling for undefined metrics
def calculate_eer(labels, predictions):
    try:
        fpr, tpr, thresholds = roc_curve(labels, predictions, pos_label=1)
        eer = fpr[np.nanargmin(np.absolute((1 - tpr - fpr)))]
    except ValueError as e:
        print(f"Error calculating EER: {e}")
        eer = None
    return eer

# Compare models
results = {}
languages = ["Original", "Japanese", "German", "Spanish", "Italian"]

for model_name, model_path in model_names.items():
    tokenizer = AutoTokenizer.from_pretrained(model_path, token=huggingface_token)
    model = AutoModelForSequenceClassification.from_pretrained(model_path, token=huggingface_token)

    model_results = {}
    for lang in languages:
        if lang == "Original":
            data = test_texts
        else:
            data = translations[lang]
        predictions = predict_emotions(data, tokenizer, model)
        acc, cm = evaluate_model(predictions, test_labels)
        eer = calculate_eer(test_labels, predictions)
        model_results[lang] = {
            "accuracy": acc,
            "confusion_matrix": cm,
            "eer": eer
        }
    results[model_name] = model_results

# Print and visualize results
for model_name, model_results in results.items():
    print(f"\n{model_name} Results:")
    for lang, result in model_results.items():
        print(f"\n{lang} Results:")
        print(f"Accuracy: {result['accuracy']}")
        print(f"EER: {result['eer']}")
        disp = ConfusionMatrixDisplay(confusion_matrix=result['confusion_matrix'],
                                      display_labels=list(emotion_labels.keys()))
        disp.plot(cmap=plt.cm.Blues)
        plt.title(f"{model_name} - {lang} Confusion Matrix")
        plt.show()
# Out:
# Translations in Japanese:
# Whaaaaaaat the heck was that? -> 何だって？
# my parents got engaged in the courtyard of [NAME] back in the 70s -> 両親は70年代に[NAME]の中庭で婚約しました
# Wow. -> わぁ。
# I know you can’t read this, but I feel really bad and hope you learn to read soon  -> あなたがこれを読むことができないのは知っていますが、私は本当に残念に思います、そしてあなたがすぐに読むことを学ぶことを願っています
# So juicy i'm surprised the man from Del Monte isn't knocking at his door. -> デルモンテの男がドアをノックしていないことに驚きました。
# If your dog is an arctic breed they will go crazy with joy and be sad that you don’t share in their happiness for the bitter cold. -> あなたの犬が北極の犬種である場合、彼らは喜びで狂い、あなたが厳しい寒さのために彼らの幸せを分かち合わないことを悲しむでしょう。
# he defended [NAME] when [NAME] drugged and butt raped a 13 year old girl -> [NAME]が13歳の少女に薬を飲ませてレイプしたとき、彼は[NAME]を擁護しました
# What? Who said I hated him? I dont give a damn about him either way. -> 何ですって？私が彼を憎んでいたなんて誰が言ったの？どっちにしても彼のことは気にしない。
# Sounds like a really bad time. Just wait till you have a nice time and place to trip. -> 大変な時期のようですね。楽しい旅の時間と場所があるまでお待ちください。
# I mean I dont think your wrong at all, but I would still be happy to fight you for funsies. -> 私はあなたが間違っているとは全く思っていませんが、私は楽しみのためにあなたと戦うことを喜んでいます。
# Fuck you I was in the bed:/ -> 俺がベッドにいたなんてクソくらえ：/
# 22 years to the day. It was uncanny. -> 22年の歳月を経て今日に至る。不思議なものだった。
# I friggin choked scrolling up to this -> こんなところまでスクロールして窒息しちゃった
# No offense, but your parents are assholes. -> 悪気はないが、君の両親はクソ野郎だ。
# Kinda reminds me of my Uncle, [NAME]. -> [NAME]さん、叔父さんを思い出します。
# My condolences. -> お悔やみを
# Wow. Of COURSE this happened -> うわー。もちろんこれは起こりました
# Which suggests nothing in itself. The same mods you claim are abusive are probably as hyperbolic about the racism issue as you are. -> それ自体は何も示唆していません。あなたが悪用していると主張する同じモッドは、おそらくあなたと同じように人種差別問題について誇張しています。
# Comments like these are the biggest reason I get so pissed off about fucking centrists crying about the "both sides" argument.  -> このようなコメントは、中道派が「両側」の議論について泣いていることに私がとても腹を立てる最大の理由です。
# As a teacher with a bunch of sick students, this scares the hell out of me. -> 病気の生徒がたくさんいる教師として、これは私を怖がらせます。
# I switched to Ally and love it. 2.2% interest is awesome -> Allyに切り替えて気に入りました。2.2%の関心は素晴らしいです
# I once looked at the I-95 and was hospitalised for weeks. -> 私はかつてI -95を見て、何週間も入院しました。
# sorry [NAME]! 😘😘😘 -> 申し訳ありませんが、[NAME]さん！ 😘😘😘
# That has to be the saddest nba account ever. Like 4 likes every post :( -> これまでで最も悲しいNBAアカウントに違いありません。すべての投稿に「いいね！」が4件あります:(
# I was wondering what that was! -> あれは何だったのかしら！
# GIVE ME OTHER PEOPLES MONEY!!!!! -> 他の人にお金をくれ！ ！ ！ ！ ！
# Omg!! They are kinda turning [NAME] into new [NAME]. -> なんてこった！ ！彼らは[name]を新しい[NAME]に変えようとしています。
# There is a surprisingly large number of [NAME] who play. -> 驚くほど多くの[NAME]がプレイしています。
# Funny, coming from the tool circle jerk reddit. -> 面白い、ツールサークルのjerk redditから来ています。
# Apologies, got a little carried away.  -> すみません、少し興奮してしまいました。
# I am glad, and enjoy. It has some pretty cool theological discussions. -> 私は嬉しく、楽しんでいます。かなりクールな神学的な議論がいくつかあります。
# This hurts me. -> これは痛いです。
# Don't call me bitch you fucking sexist. I bet you are one of those white devils. How many women and minorities have you suppressed today? -> 私をビッチと呼ばないでください、あなたは性差別主義者です。きっとあなたもあの白い悪魔の一人でしょう。今日、何人の女性やマイノリティを抑圧しましたか？
# I miss being practically jello as a kid -> 子供の頃にゼリーっぽくなったのが懐かしいです
# Wow random irrelevant internet person has the secret goods on [NAME]. Maybe we’ll finally get to the bottom of this birth certificate thing... -> WOWランダムな無関係なインターネット関係者が[NAME]に秘密の商品を持っています。やっとこの出生証明書の真相を突き止めることができるかもしれません...
# I always wondered why that never happened with the “muscles from Brussels” in any of his movies. -> 私はいつも、なぜ彼の映画の「ブリュッセルの筋肉」でそれが起こらなかったのか疑問に思っていました。
# Would I rather be feared or loved? Easy. Both. I want people to be afraid of how much they love me. -> 私は恐れられたいですか、それとも愛されたいですか？簡単です。どちらも。私をどれだけ愛しているかを人々に恐れてもらいたいのです。
# I got mine a few months ago and honestly apprehensive to wear it out to a game in fear of staining it. -> 私は数ヶ月前に私のものを手に入れましたが、正直なところ、それを汚すことを恐れてゲームに磨耗することを心配していました。
# Someone get fat boy [NAME] a happy meal. -> 誰かが太った男の子[NAME]を幸せな食事にしてください。
# Holy fuck, report this now. The fuck you doing on reddit?  -> なんてこった、今すぐ報告しろ。Redditで何してるんだ？
# Company car? Oh boy he’s in trouble now. -> 社用車？ああ、彼は今困っている。
# I visibly recoiled from that. -> 私は目に見えてそれから後退しました。
# I’m just gonna go ahead and call bullshit on most of the details of this story. -> 私はこの話の詳細のほとんどについてくだらない話をするつもりです。
# Same here. My refund almost doubled from last year. I almost cried when I saw how much I'm getting back. -> こちらも同じです。払い戻しは昨年のほぼ2倍になりました。どれだけ戻ってくるかを見て、私は泣きそうになった。
# You shouldn't force someone to come out you know. Now look at what you did! You killed [NAME]! You bastard! -> あなたが知っている誰かに出てくるように強制するべきではありません。さて、あなたがしたことを見てください！ [NAME]を殺したのね！この野郎！
# Too right. I hate the Sun. worst tabloid out there -> 正解です。私は太陽が大嫌いです。最悪のタブロイド紙です
# Son of a bitch... here we go. Can't just stand there guys.... -> くそったれ...行くぞ。そこに立っているだけではダメだ……
# Nothing more Jersey than the sound of car horns over [NAME] rambling out an annoyed answer to a caller. -> [NAME]が発信者に迷惑な返事をしている車のホーンの音以上のものはありません。
# So so good -> とても良い
# Fucking and being a boy -> ファックして男の子になる
# Sorry. This happens to too many good people. -> 申し訳ありません。これはあまりにも多くの善良な人々に起こります。
# And when the 4th Quarter needed it most, it vanished! -> そして、第4クォーターが最もそれを必要としていたとき、それは消えました！
# Luckily he is not. -> 幸運なことに、彼はそうではありません。
# Here did you know that [NAME] slept with 35,000 women. Outrageous. -> ここでは、[NAME]が35,000人の女性と寝たことを知っていました。とんでもない。
# Didn’t know if you knew, so I was just trying to give context to your statement. Sorry.  -> あなたが知っているかどうかわからなかったので、私はちょうどあなたの声明に文脈を与えようとしていました。ごめんなさい。
# Not gonna happen, pure delusion I *aggressively* call this ridiculous bluff -> そんなことはない、純粋な妄想私は*積極的に*このばかげたハッタリと呼ぶ
# WHY THE FUCK IS BAYLESS ISOING -> 一体なぜベイレスISOINGなのか
# It's because you play against 1000 ms ping EU players that have no idea what's going on. Happy hunting! -> それは、何が起こっているのかわからない1000ミリ秒のping EUプレイヤーと対戦するからです。ハッピーハンティング！
# You're saying some surprisingly stupid things for someone named "[NAME]." -> あなたは「[ NAME ]」という名前の人に驚くほど馬鹿げたことを言っています。
# By [NAME]! That’s [NAME] music! -> [name]さん！[ NAME]さんの音楽です！
# Dont keep your mouth shut. -> 黙ってて。
# Comments like these are the biggest reason I get so pissed off about fucking centrists crying about the "both sides" argument.  -> Kommentare wie diese sind der Hauptgrund, warum ich so sauer darauf bin, dass verdammte Zentristen über das Argument "beide Seiten" weinen.
# As a teacher with a bunch of sick students, this scares the hell out of me. -> Als Lehrer mit einem Haufen kranker Schüler macht mir das höllische Angst.
# I switched to Ally and love it. 2.2% interest is awesome -> Ich bin zu Ally gewechselt und liebe es. 2,2 % Zinsen sind fantastisch
# I once looked at the I-95 and was hospitalised for weeks. -> Ich habe mir einmal die I-95 angeschaut und war wochenlang im Krankenhaus.
# sorry [NAME]! 😘😘😘 -> entschuldigung, [NAME]! 😘😘😘
# That has to be the saddest nba account ever. Like 4 likes every post :( -> Das muss das traurigste NBA-Konto aller Zeiten sein. Gefällt mir 4 mag jeden Beitrag :(
# I was wondering what that was! -> Oh, ich wollte nur wissen, was das war.
# GIVE ME OTHER PEOPLES MONEY!!!!! -> GIB MIR DAS GELD ANDERER LEUTE!!!!!
# Omg!! They are kinda turning [NAME] into new [NAME]. -> Omg!! Sie verwandeln [NAME] irgendwie in neues [NAME].
# There is a surprisingly large number of [NAME] who play. -> Es gibt eine überraschend große Anzahl von [NAME], die spielen.
# Funny, coming from the tool circle jerk reddit. -> Komisch, aus dem Tool Circle Jerk Reddit.
# Apologies, got a little carried away.  -> Entschuldigung, ich habe mich ein wenig mitreißen lassen.
# I am glad, and enjoy. It has some pretty cool theological discussions. -> Ich bin froh und genieße es. Es gibt einige ziemlich coole theologische Diskussionen.
# This hurts me. -> Das tut mir weh.
# Don't call me bitch you fucking sexist. I bet you are one of those white devils. How many women and minorities have you suppressed today? -> Nenn mich nicht Schlampe, du verdammter Sexist. Ich wette, du bist einer dieser weißen Teufel. Wie viele Frauen und Minderheiten haben Sie heute unterdrückt?
# I miss being practically jello as a kid -> Ich vermisse es, als Kind praktisch Jello zu sein
# Wow random irrelevant internet person has the secret goods on [NAME]. Maybe we’ll finally get to the bottom of this birth certificate thing... -> Wow zufällige irrelevante Internetperson hat die geheimen Waren auf [NAME]. Vielleicht gehen wir dieser Sache mit der Geburtsurkunde endlich auf den Grund...
# I always wondered why that never happened with the “muscles from Brussels” in any of his movies. -> Ich habe mich immer gefragt, warum das in keinem seiner Filme mit den „Muskeln aus Brüssel“ passiert ist.
# Would I rather be feared or loved? Easy. Both. I want people to be afraid of how much they love me. -> Würde ich lieber gefürchtet oder geliebt werden? Einfach. Beides. Ich möchte, dass die Leute Angst davor haben, wie sehr sie mich lieben.
# I got mine a few months ago and honestly apprehensive to wear it out to a game in fear of staining it. -> Ich habe meine vor ein paar Monaten bekommen und bin ehrlich besorgt, sie zu einem Spiel zu tragen, aus Angst, sie zu färben.
# Someone get fat boy [NAME] a happy meal. -> Jemand holt dem dicken Jungen [NAME] ein fröhliches Essen.
# Holy fuck, report this now. The fuck you doing on reddit?  -> Heilige Scheiße, melde das jetzt. Was zum Teufel machst du auf Reddit?
# Company car? Oh boy he’s in trouble now. -> Firmenwagen? Oh Mann, er ist jetzt in Schwierigkeiten.
# I visibly recoiled from that. -> Davon habe ich mich sichtlich beschimpft.
# I’m just gonna go ahead and call bullshit on most of the details of this story. -> Ich werde einfach weitermachen und die meisten Details dieser Geschichte als Blödsinn bezeichnen.
# Same here. My refund almost doubled from last year. I almost cried when I saw how much I'm getting back. -> Gleiches gilt hier. Meine Rückerstattung hat sich gegenüber dem letzten Jahr fast verdoppelt. Ich weinte fast, als ich sah, wie viel ich zurückbekomme.
# You shouldn't force someone to come out you know. Now look at what you did! You killed [NAME]! You bastard! -> Du solltest niemanden zwingen, sich zu outen, weißt du. Sieh dir an, was du getan hast! Du hast [NAME] getötet! Du Bastard!
# Too right. I hate the Sun. worst tabloid out there -> Zu Recht. Ich hasse die Sonne. Schlimmste Boulevardzeitung da draußen
# Son of a bitch... here we go. Can't just stand there guys.... -> Hurensohn... los geht 's. Ich kann nicht einfach da stehen, Leute...
# Nothing more Jersey than the sound of car horns over [NAME] rambling out an annoyed answer to a caller. -> Nichts weiter als das Geräusch von Autohupen über [NAME], die eine verärgerte Antwort an einen Anrufer ausbreiten.
# So so good -> so so good!
# Fucking and being a boy -> Ficken und ein Junge sein
# Sorry. This happens to too many good people. -> Tut mir leid. Das passiert zu vielen guten Leuten.
# And when the 4th Quarter needed it most, it vanished! -> Und als das 4. Quartal es am meisten brauchte, verschwand es!
# Luckily he is not. -> Zum Glück ist er das nicht.
# Here did you know that [NAME] slept with 35,000 women. Outrageous. -> Hier wussten Sie, dass [NAME] mit 35.000 Frauen geschlafen hat. Ungeheuerlich.
# Didn’t know if you knew, so I was just trying to give context to your statement. Sorry.  -> Ich wusste nicht, ob du es wusstest, also habe ich nur versucht, deiner Aussage einen Kontext zu geben. Tut mir leid.
# Not gonna happen, pure delusion I *aggressively* call this ridiculous bluff -> Wird nicht passieren, reine Täuschung nenne ich *aggressiv* diesen lächerlichen Bluff
# WHY THE FUCK IS BAYLESS ISOING -> WARUM ZUM TEUFEL IST BAYLESS ISOING
# It's because you play against 1000 ms ping EU players that have no idea what's going on. Happy hunting! -> Das liegt daran, dass du gegen 1000 ms ping EU-Spieler spielst, die keine Ahnung haben, was los ist. Viel Spaß beim Jagen!
# You're saying some surprisingly stupid things for someone named "[NAME]." -> Du sagst einige überraschend dumme Dinge für jemanden namens "[NAME]".
# By [NAME]! That’s [NAME] music! -> Von [NAME]! Das ist [NAME] Musik!
# Dont keep your mouth shut. -> Halt den Mund.
# I don't filter it out because I enjoy my daily cringe from the constant open letters. "To the ____ who ____" -> Ich filtere es nicht heraus, weil ich mein tägliches Zucken vor den ständigen offenen Briefen genieße. "An die ____ WHO ____"
#
# Translations in Spanish:
# Whaaaaaaat the heck was that? -> ¿Qué diablos fue eso?
# my parents got engaged in the courtyard of [NAME] back in the 70s -> mis padres se comprometieron en el patio de [NOMBRE] en los años 70
# Didn’t know if you knew, so I was just trying to give context to your statement. Sorry.  -> No sabía si lo sabías, así que solo estaba tratando de dar contexto a tu declaración. Lo siento.
# Not gonna happen, pure delusion I *aggressively* call this ridiculous bluff -> No va a suceder, pura ilusión, yo *agresivamente* llamo a esto un ridículo farol
# WHY THE FUCK IS BAYLESS ISOING -> WHY THE FUCK IS BAYLESS ISOING
# It's because you play against 1000 ms ping EU players that have no idea what's going on. Happy hunting! -> Es porque juegas contra jugadores de ping de 1000 ms de la UE que no tienen idea de lo que está pasando. ¡Feliz caza!
# You're saying some surprisingly stupid things for someone named "[NAME]." -> Estás diciendo algunas cosas sorprendentemente estúpidas para alguien llamado "[NOMBRE]".
# By [NAME]! That’s [NAME] music! -> ¡Por [NAME]! ¡Eso es música de [NAME]!
# Dont keep your mouth shut. -> ¡Mantén la boca cerrada!
# I don't filter it out because I enjoy my daily cringe from the constant open letters. "To the ____ who ____" -> No lo filtro porque disfruto mi vergüenza diaria de las constantes cartas abiertas. "Para el ____ que ____"
#
# Translations in Italian:
# Whaaaaaaat the heck was that? -> Che diavolo era quello?
# my parents got engaged in the courtyard of [NAME] back in the 70s -> i miei genitori si sono fidanzati nel cortile di [NOME] negli anni '70
# Wow. -> Wow.
# I know you can’t read this, but I feel really bad and hope you learn to read soon  -> So che non puoi leggerlo, ma mi sento davvero male e spero che imparerai a leggere presto
# So juicy i'm surprised the man from Del Monte isn't knocking at his door. -> Così succoso che mi sorprende che l'uomo di Del Monte non stia bussando alla sua porta.
# If your dog is an arctic breed they will go crazy with joy and be sad that you don’t share in their happiness for the bitter cold. -> Se il tuo cane è una razza artica, impazzirà di gioia e sarà triste che tu non condivida la sua felicità per il freddo pungente.
# he defended [NAME] when [NAME] drugged and butt raped a 13 year old girl -> ha difeso [NOME] quando [NOME] ha drogato e violentato una ragazza di 13 anni
# What? Who said I hated him? I dont give a damn about him either way. -> Cosa? Chi ha detto che lo odiavo? Non me ne frega niente di lui in ogni caso.
# Oh really? I didn’t know someone else posted it haha Edit: just looked and someone posted it right after me -> Oh davvero? Non sapevo che qualcun altro l'avesse pubblicato haha Modifica: ho solo guardato e qualcuno l'ha pubblicato subito dopo di me
# [NAME]! -> Nome
# No, they couldn’t hav- They shouldn’t have. uh...this makes me feel sick 🤕  -> No, non potevano avere- Non avrebbero dovuto. uh...questo mi fa stare male 🤕
# This draft is one man deep tbh. Not getting Zion would be devastating and a waste of a whole year. -> Questa bozza è un uomo profondo tbh. Non ottenere Zion sarebbe stato devastante e uno spreco di un anno intero.
# Fucking fuck! 2 (or more) sets of fucking socks in fucking sandals. -> Cazzo, cazzo! 2 (o più) paia di calzini del cazzo con dei sandali del cazzo.
# How is one not amused by that? I can't imagine being angry even if it was my lunch. lmao... -> Come si fa a non divertirsi? Non riesco a immaginare di essere arrabbiato anche se fosse il mio pranzo. lmao...
# Mommy bad man!!! -> Mamma uomo cattivo!!!
# It's sad that we have to think of it as a miracle and not a regular occurrence :/ -> È triste doverlo considerare un miracolo e non un evento normale:/
# Well fuck my kids then -> Beh, che si fottano i miei figli
# my brain hurts... -> mi fa male il cervello...
# A year ago I said that this continuous ISO by Houston is disgusting to watch. It s still disgusting. -> Un anno fa ho detto che questo ISO continuo di Houston è disgustoso da guardare. È ancora disgustoso.
# This hurts to watch -> Fa male da guardare
# And that's an issue. Councils are *so* unrepresentative it hurts. -> E questo è un problema. I consigli sono *così* non rappresentativi che fa male.
# This is pretty worrying and makes me wonder why she can’t. That’s not normal. -> Questo è piuttosto preoccupante e mi fa chiedere perché non possa farlo. Non è normale.
# Ok, then what the actual fuck is your plan? -> Ok, allora qual è il tuo vero piano?
# I wouldn't be surprised if the Cheetos dust was coming out of his sweat. -> Non sarei sorpreso se la polvere di Cheetos stesse uscendo dal suo sudore.
# That's just....sorry, but stupid is the only correct word. -> È solo...scusa, ma stupida è l'unica parola corretta.
# My worst fear when I finally get over someone Those damn what ifs -> La mia peggiore paura quando finalmente mi dimentico di qualcuno Quei dannati se
# Cheers, I will do  -> Cheers, I will do
# Finally, one win for the war on drugs! -> Finalmente una vittoria per la guerra alla droga!
# Eat my fuck- [NAME] -> Mangia il mio cazzo- [NOME]
# [NAME] Wednesday’s 😎 Good to know he’s enjoying the retirement life.  -> [NOME] Mercoledì è 😎 bello sapere che si sta godendo la vita pensionistica.
# No, I generally feel like slugging them in the head repeatedly with an iron bar. Spitting is just petty. *Let your hatred flow!* -> No, in genere ho voglia di colpirli ripetutamente in testa con una sbarra di ferro. Sputare è solo meschino. *Lascia fluire il tuo odio!*
# I'm saying put up or shut up. If you can't back up your point with evidence, your opinion is worthless.  -> Sto dicendo di stare in piedi o di stare zitto. Se non riesci a sostenere il tuo punto di vista con prove, la tua opinione è inutile.
# For as long as she’s been gone, I’m terrified to think why she was kept alive that long. -> Da quando se n' è andata, ho il terrore di pensare al motivo per cui è stata tenuta in vita così a lungo.
# fuck atheist countries -> fanculo i paesi atei
# Which is odd, he was terrible on Sunday -> Il che è strano, è stato terribile domenica
# And..the reality of it hurts -> E..la realtà fa male
# No he was given a bad team to work with unfortunately, and never got the final shot he deserved :( -> No, sfortunatamente gli è stata data una brutta squadra con cui lavorare e non ha mai avuto la possibilità finale che meritava :(
# Doing a happy dance! Yay! -> Fare un ballo allegro! Evviva!
# I feel your pain 😪 i got scammed $1400 in November. I felt like a dumbass for falling for it too. -> Sento che il tuo dolore 😪 mi ha fregato $1400 a novembre. Anch' io mi sentivo un idiota per essermi innamorato.
# I'm fucking starving here. -> Sto morendo di fame
# ...
# I always thought filet mignon had bacon and garlic butter. Colour me surprised Deliberately ignoring anything to do with the minion -> Ho sempre pensato che il filetto mignon avesse pancetta e burro all'aglio. Colora la mia sorpresa Ignorando deliberatamente qualsiasi cosa abbia a che fare con il tirapiedi
# Sounds like a really bad time. Just wait till you have a nice time and place to trip. -> Sembra davvero un brutto momento. Aspetta solo di avere un bel momento e un bel posto in cui viaggiare.
# I mean I dont think your wrong at all, but I would still be happy to fight you for funsies. -> Voglio dire, non penso affatto che tu abbia torto, ma sarei comunque felice di combatterti per divertimento.
# Fuck you I was in the bed:/ -> Vaffanculo, ero a letto:/
# 22 years to the day. It was uncanny. -> 22 anni al giorno. Era inquietante.
# I friggin choked scrolling up to this -> Mi sono soffocato scorrendo verso l'alto fino a questo
# No offense, but your parents are assholes. -> Senza offesa, ma i tuoi genitori sono degli stronzi.
# Kinda reminds me of my Uncle, [NAME]. -> Mi ricorda un po' mio zio, [NOME].
# My condolences. -> Le mie condoglianze.
# Wow. Of COURSE this happened -> Wow. CERTO CHE è successo
# Which suggests nothing in itself. The same mods you claim are abusive are probably as hyperbolic about the racism issue as you are. -> Il che non suggerisce nulla di per sé. Le stesse mod che sostieni siano abusive sono probabilmente iperboliche sul problema del razzismo quanto te.
# Comments like these are the biggest reason I get so pissed off about fucking centrists crying about the "both sides" argument.  -> Commenti come questi sono il motivo principale per cui mi arrabbio così tanto per i fottuti centristi che piangono per la discussione "da entrambe le parti".
# As a teacher with a bunch of sick students, this scares the hell out of me. -> Come insegnante con un gruppo di studenti malati, questo mi spaventa a morte.
# I switched to Ally and love it. 2.2% interest is awesome -> Sono passato ad Ally e l'adoro. L'interesse del 2,2% è fantastico
# I once looked at the I-95 and was hospitalised for weeks. -> Una volta ho guardato l'I-95 e sono stato ricoverato in ospedale per settimane.
# sorry [NAME]! 😘😘😘 -> Scusa, [nome].
# That has to be the saddest nba account ever. Like 4 likes every post :( -> Dev' essere l'account nba più triste di sempre. Mi piace 4 Mi piace ogni post :(
# I was wondering what that was! -> Mi chiedevo cosa fosse!
# GIVE ME OTHER PEOPLES MONEY!!!!! -> DATEMI I SOLDI DEGLI ALTRI!!!!!
# Omg!! They are kinda turning [NAME] into new [NAME]. -> Accidenti!! Stanno trasformando [NOME] in un nuovo [NOME].
# There is a surprisingly large number of [NAME] who play. -> C'è un numero sorprendentemente elevato di [NOME] che giocano.
# Funny, coming from the tool circle jerk reddit. -> Divertente, proveniente dal cerchio degli attrezzi jerk reddit.
# Apologies, got a little carried away.  -> Mi scuso, mi sono lasciato un po' trasportare.
# I am glad, and enjoy. It has some pretty cool theological discussions. -> Sono contento e mi diverto. Ha alcune discussioni teologiche piuttosto interessanti.
# This hurts me. -> Questo mi fa male.
# Don't call me bitch you fucking sexist. I bet you are one of those white devils. How many women and minorities have you suppressed today? -> Non chiamarmi stronza, fottuta sessista. Scommetto che sei uno di quei diavoli bianchi. Quante donne e minoranze hai soppresso oggi?
# I miss being practically jello as a kid -> Mi manca essere praticamente gelatina da bambino
# Wow random irrelevant internet person has the secret goods on [NAME]. Maybe we’ll finally get to the bottom of this birth certificate thing... -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 39 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# I always wondered why that never happened with the “muscles from Brussels” in any of his movies. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 38 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Would I rather be feared or loved? Easy. Both. I want people to be afraid of how much they love me. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 36 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# I got mine a few months ago and honestly apprehensive to wear it out to a game in fear of staining it. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 35 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Someone get fat boy [NAME] a happy meal. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 34 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Holy fuck, report this now. The fuck you doing on reddit?  -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 32 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Company car? Oh boy he’s in trouble now. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 31 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# I visibly recoiled from that. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 30 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# I’m just gonna go ahead and call bullshit on most of the details of this story. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 29 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Same here. My refund almost doubled from last year. I almost cried when I saw how much I'm getting back. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 27 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# You shouldn't force someone to come out you know. Now look at what you did! You killed [NAME]! You bastard! -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 26 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Too right. I hate the Sun. worst tabloid out there -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 25 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Son of a bitch... here we go. Can't just stand there guys.... -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 24 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Nothing more Jersey than the sound of car horns over [NAME] rambling out an annoyed answer to a caller. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 22 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# So so good -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 21 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Fucking and being a boy -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 20 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Sorry. This happens to too many good people. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 18 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# And when the 4th Quarter needed it most, it vanished! -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 17 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Luckily he is not. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 16 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Here did you know that [NAME] slept with 35,000 women. Outrageous. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 15 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Didn’t know if you knew, so I was just trying to give context to your statement. Sorry.  -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 13 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Not gonna happen, pure delusion I *aggressively* call this ridiculous bluff -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 12 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# WHY THE FUCK IS BAYLESS ISOING -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 11 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# It's because you play against 1000 ms ping EU players that have no idea what's going on. Happy hunting! -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 10 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# You're saying some surprisingly stupid things for someone named "[NAME]." -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 08 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# By [NAME]! That’s [NAME] music! -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 07 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# Dont keep your mouth shut. -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 06 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# I don't filter it out because I enjoy my daily cringe from the constant open letters. "To the ____ who ____" -> MYMEMORY WARNING: YOU USED ALL AVAILABLE FREE TRANSLATIONS FOR TODAY. NEXT AVAILABLE IN  23 HOURS 53 MINUTES 04 SECONDS VISIT HTTPS://MYMEMORY.TRANSLATED.NET/DOC/USAGELIMITS.PHP TO TRANSLATE MORE
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/294 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/329M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/291 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/768 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/268M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/338 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/843k [00:00<?, ?B/s]
# bpe.codes:   0%|          | 0.00/1.08M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/167 [00:00<?, ?B/s]
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# config.json:   0%|          | 0.00/949 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/540M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/734 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
# Some weights of the model checkpoint at joeddav/xlm-roberta-large-xnli were not used when initializing XLMRobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# RoBERTa Results:
#
# Original Results:
# Accuracy: 0.017857142857142856
# EER: 0.2967032967032967
# Japanese Results:
# Accuracy: 0.1875
# EER: 0.978021978021978
# German Results:
# Accuracy: 0.125
# EER: 0.6373626373626373
# Spanish Results:
# Accuracy: 0.11607142857142858
# EER: 0.7252747252747253
# Italian Results:
# Accuracy: 0.16071428571428573
# EER: 0.8571428571428571
# DistilBERT Results:
#
# Original Results:
# Accuracy: 0.09821428571428571
# EER: 0.6593406593406593
# Japanese Results:
# Accuracy: 0.1875
# EER: 0.054945054945054944
# German Results:
# Accuracy: 0.125
# EER: 0.8681318681318682
# Spanish Results:
# Accuracy: 0.125
# EER: 0.34065934065934067
# Italian Results:
# Accuracy: 0.13392857142857142
# EER: 0.2967032967032967
# BERT Results:
#
# Original Results:
# Accuracy: 0.07142857142857142
# EER: 0.32967032967032966
# Japanese Results:
# Accuracy: 0.16964285714285715
# EER: 0.989010989010989
# German Results:
# Accuracy: 0.13392857142857142
# EER: 0.9230769230769231
# Spanish Results:
# Accuracy: 0.15178571428571427
# EER: 0.9010989010989011
# Italian Results:
# Accuracy: 0.16964285714285715
# EER: 0.945054945054945
# XLM-RoBERTa Results:
#
# Original Results:
# Accuracy: 0.20535714285714285
# EER: 0.21978021978021978
# Japanese Results:
# Accuracy: 0.19642857142857142
# EER: 0.4065934065934066
# German Results:
# Accuracy: 0.22321428571428573
# EER: 0.3626373626373626
# Spanish Results:
# Accuracy: 0.19642857142857142
# EER: 0.38461538461538464
# Italian Results:
# Accuracy: 0.14285714285714285
# EER: 0.1978021978021978
